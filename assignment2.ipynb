# %%
import gymnasium as gym
import numpy as np
if not hasattr(np, "bool8"):
    np.bool8 = np.bool_
from stable_baselines3 import DQN

# %%
env = gym.make("CartPole-v1")

model = DQN(
    policy="MlpPolicy",
    env=env,
    learning_rate=5e-4,           
    buffer_size=50000,               
    learning_starts=1000,
    batch_size=64,                   
    tau=1.0,
    gamma=0.995,                    
    train_freq=1,
    target_update_interval=500,      
    exploration_fraction=0.05,       
    exploration_final_eps=0.01,      
    max_grad_norm=10,
    policy_kwargs=dict(net_arch=[128, 128]),
    verbose=1
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=100000)
# Out:
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 16       |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 3638     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 64       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.5     |
# |    ep_rew_mean      | 19.5     |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 3595     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 156      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 3770     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 247      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 3403     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 324      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.916    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 3146     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 422      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 3276     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 508      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.88     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 3679     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 606      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.861    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 4033     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 704      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.844    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 4275     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 789      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.83     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 4535     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 860      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.803    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 4935     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 993      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.79     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 3031     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1062     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00961  |
# |    n_updates        | 61       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.9     |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.765    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1383     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1189     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.000211 |
# |    n_updates        | 188      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.754    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1141     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1242     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 9.2e-05  |
# |    n_updates        | 241      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.739    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 940      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1316     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 8.47e-05 |
# |    n_updates        | 315      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.8     |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.723    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 798      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1397     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.000105 |
# |    n_updates        | 396      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.707    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 702      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1478     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 8.12e-05 |
# |    n_updates        | 477      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.693    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 639      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1552     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0215   |
# |    n_updates        | 551      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.679    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 592      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1623     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0317   |
# |    n_updates        | 622      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.664    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 551      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1696     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0107   |
# |    n_updates        | 695      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.652    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 518      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1757     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0215   |
# |    n_updates        | 756      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.64     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 485      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1817     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0167   |
# |    n_updates        | 816      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.628    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 457      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1879     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.022    |
# |    n_updates        | 878      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.3     |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.615    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 435      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1945     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0217   |
# |    n_updates        | 944      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.601    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 417      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2013     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.188    |
# |    n_updates        | 1012     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.586    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 399      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 2089     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.016    |
# |    n_updates        | 1088     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.9     |
# |    ep_rew_mean      | 19.9     |
# |    exploration_rate | 0.574    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 387      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 2151     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0387   |
# |    n_updates        | 1150     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.9     |
# |    ep_rew_mean      | 19.9     |
# |    exploration_rate | 0.557    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 371      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 2237     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0437   |
# |    n_updates        | 1236     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20       |
# |    ep_rew_mean      | 20       |
# |    exploration_rate | 0.54     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 358      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 2322     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.059    |
# |    n_updates        | 1321     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.524    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 347      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 2406     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.051    |
# |    n_updates        | 1405     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.6     |
# |    ep_rew_mean      | 19.6     |
# |    exploration_rate | 0.512    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 340      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 2464     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0838   |
# |    n_updates        | 1463     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.3     |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.498    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 333      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 2533     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0945   |
# |    n_updates        | 1532     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19       |
# |    ep_rew_mean      | 19       |
# |    exploration_rate | 0.484    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 325      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 2607     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0733   |
# |    n_updates        | 1606     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.1     |
# |    ep_rew_mean      | 19.1     |
# |    exploration_rate | 0.465    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 317      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 2700     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0294   |
# |    n_updates        | 1699     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.7     |
# |    ep_rew_mean      | 19.7     |
# |    exploration_rate | 0.439    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 307      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 2834     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.046    |
# |    n_updates        | 1833     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.4     |
# |    ep_rew_mean      | 19.4     |
# |    exploration_rate | 0.419    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 300      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 2935     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0148   |
# |    n_updates        | 1934     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.39     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 292      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 3081     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.066    |
# |    n_updates        | 2080     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.4     |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.301    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 272      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 3532     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.102    |
# |    n_updates        | 2531     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.4     |
# |    ep_rew_mean      | 26.4     |
# |    exploration_rate | 0.23     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 261      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 3887     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0269   |
# |    n_updates        | 2886     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.7     |
# |    ep_rew_mean      | 32.7     |
# |    exploration_rate | 0.092    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 244      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 4586     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.013    |
# |    n_updates        | 3585     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.2     |
# |    ep_rew_mean      | 41.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 230      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 5514     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.
|
# |    ep_rew_mean      | 86       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 195      |
# |    time_elapsed     | 123      |
# |    total_timesteps  | 24073    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0474   |
# |    n_updates        | 23072    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86       |
# |    ep_rew_mean      | 86       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 195      |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 24421    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.139    |
# |    n_updates        | 23420    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.3     |
# |    ep_rew_mean      | 86.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 194      |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 24791    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.099    |
# |    n_updates        | 23790    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.7     |
# |    ep_rew_mean      | 86.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 194      |
# |    time_elapsed     | 129      |
# |    total_timesteps  | 25171    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.108    |
# |    n_updates        | 24170    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.1     |
# |    ep_rew_mean      | 87.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 194      |
# |    time_elapsed     | 131      |
# |    total_timesteps  | 25542    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0426   |
# |    n_updates        | 24541    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.7     |
# |    ep_rew_mean      | 87.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 194      |
# |    time_elapsed     | 133      |
# |    total_timesteps  | 25925    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0777   |
# |    n_updates        | 24924    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.9     |
# |    ep_rew_mean      | 87.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 193      |
# |    time_elapsed     | 135      |
# |    total_timesteps  | 26276    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.401    |
# |    n_updates        | 25275    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.1     |
# |    ep_rew_mean      | 88.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 193      |
# |    time_elapsed     | 137      |
# |    total_timesteps  | 26624    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.248    |
# |    n_updates        | 25623    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.3     |
# |    ep_rew_mean      | 88.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 193      |
# |    time_elapsed     | 139      |
# |    total_timesteps  | 26980    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0748   |
# |    n_updates        | 25979    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.5     |
# |    ep_rew_mean      | 88.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 193      |
# |    time_elapsed     | 141      |
# |    total_timesteps  | 27366    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0217   |
# |    n_updates        | 26365    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89       |
# |    ep_rew_mean      | 89       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 193      |
# |    time_elapsed     | 143      |
# |    total_timesteps  | 27745    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.022    |
# |    n_updates        | 26744    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.1     |
# |    ep_rew_mean      | 89.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 192      |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 28119    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0907   |
# |    n_updates        | 27118    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.5     |
# |    ep_rew_mean      | 89.5     |
# |    exploration_rate | 0.01     |
# ...
# |    time_elapsed     | 275      |
# |    total_timesteps  | 51091    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0321   |
# |    n_updates        | 50090    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 181      |
# |    ep_rew_mean      | 181      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 184      |
# |    time_elapsed     | 286      |
# |    total_timesteps  | 53022    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0416   |
# |    n_updates        | 52021    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 196      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 184      |
# |    time_elapsed     | 298      |
# |    total_timesteps  | 55022    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0682   |
# |    n_updates        | 54021    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 211      |
# |    ep_rew_mean      | 211      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 183      |
# |    time_elapsed     | 310      |
# |    total_timesteps  | 57022    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0327   |
# |    n_updates        | 56021    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 223      |
# |    ep_rew_mean      | 223      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 183      |
# |    time_elapsed     | 322      |
# |    total_timesteps  | 59022    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0531   |
# |    n_updates        | 58021    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 237      |
# |    ep_rew_mean      | 237      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 182      |
# |    time_elapsed     | 334      |
# |    total_timesteps  | 61022    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0305   |
# |    n_updates        | 60021    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 251      |
# |    ep_rew_mean      | 251      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 181      |
# |    time_elapsed     | 346      |
# |    total_timesteps  | 63022    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.103    |
# |    n_updates        | 62021    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 266      |
# |    ep_rew_mean      | 266      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 180      |
# |    time_elapsed     | 359      |
# |    total_timesteps  | 65022    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0492   |
# |    n_updates        | 64021    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 278      |
# |    ep_rew_mean      | 278      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 179      |
# |    time_elapsed     | 370      |
# |    total_timesteps  | 66716    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0868   |
# |    n_updates        | 65715    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 293      |
# |    ep_rew_mean      | 293      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 178      |
# |    time_elapsed     | 384      |
# |    total_timesteps  | 68716    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.016    |
# |    n_updates        | 67715    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 307      |
# |    ep_rew_mean      | 307      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 177      |
# |    time_elapsed     | 397      |
# |    total_timesteps  | 70716    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0242   |
# |    n_updates        | 69715    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 322      |
# |    ep_rew_mean      | 322      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 176      |
# |    time_elapsed     | 411      |
# |    total_timesteps  | 72716    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0269   |
# |    n_updates        | 71715    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 337      |
# |    ep_rew_mean      | 337      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 175      |
# |    time_elapsed     | 424      |
# |    total_timesteps  | 74716    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0364   |
# |    n_updates        | 73715    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 351      |
# |    ep_rew_mean      | 351      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 174      |
# |    time_elapsed     | 438      |
# |    total_timesteps  | 76716    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0565   |
# |    n_updates        | 75715    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 365      |
# |    ep_rew_mean      | 365      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 174      |
# |    time_elapsed     | 452      |
# |    total_timesteps  | 78716    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0421   |
# |    n_updates        | 77715    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 379      |
# |    ep_rew_mean      | 379      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 173      |
# |    time_elapsed     | 466      |
# |    total_timesteps  | 80716    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0212   |
# |    n_updates        | 79715    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 384      |
# |    ep_rew_mean      | 384      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 172      |
# |    time_elapsed     | 473      |
# |    total_timesteps  | 81715    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0387   |
# |    n_updates        | 80714    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 395      |
# |    ep_rew_mean      | 395      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 172      |
# |    time_elapsed     | 484      |
# |    total_timesteps  | 83383    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0164   |
# |    n_updates        | 82382    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 403      |
# |    ep_rew_mean      | 403      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 171      |
# |    time_elapsed     | 492      |
# |    total_timesteps  | 84672    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.239    |
# |    n_updates        | 83671    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 405      |
# |    ep_rew_mean      | 405      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 612      |
# |    fps              | 171      |
# |    time_elapsed     | 498      |
# |    total_timesteps  | 85450    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0139   |
# |    n_updates        | 84449    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 420      |
# |    ep_rew_mean      | 420      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 616      |
# |    fps              | 170      |
# |    time_elapsed     | 511      |
# |    total_timesteps  | 87450    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0132   |
# |    n_updates        | 86449    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 433      |
# |    ep_rew_mean      | 433      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 620      |
# |    fps              | 170      |
# |    time_elapsed     | 525      |
# |    total_timesteps  | 89390    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00681  |
# |    n_updates        | 88389    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 435      |
# |    ep_rew_mean      | 435      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 624      |
# |    fps              | 170      |
# |    time_elapsed     | 530      |
# |    total_timesteps  | 90260    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0107   |
# |    n_updates        | 89259    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 433      |
# |    ep_rew_mean      | 433      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 628      |
# |    fps              | 169      |
# |    time_elapsed     | 534      |
# |    total_timesteps  | 90762    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.013    |
# |    n_updates        | 89761    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 424      |
# |    ep_rew_mean      | 424      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 632      |
# |    fps              | 169      |
# |    time_elapsed     | 539      |
# |    total_timesteps  | 91495    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0113   |
# |    n_updates        | 90494    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 415      |
# |    ep_rew_mean      | 415      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 636      |
# |    fps              | 169      |
# |    time_elapsed     | 546      |
# |    total_timesteps  | 92563    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0883   |
# |    n_updates        | 91562    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 408      |
# |    ep_rew_mean      | 408      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 640      |
# |    fps              | 169      |
# |    time_elapsed     | 554      |
# |    total_timesteps  | 93778    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0219   |
# |    n_updates        | 92777    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 402      |
# |    ep_rew_mean      | 402      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 644      |
# |    fps              | 168      |
# |    time_elapsed     | 563      |
# |    total_timesteps  | 95188    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0309   |
# |    n_updates        | 94187    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 394      |
# |    ep_rew_mean      | 394      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 648      |
# |    fps              | 168      |
# |    time_elapsed     | 572      |
# |    total_timesteps  | 96426    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0141   |
# |    n_updates        | 95425    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 390      |
# |    ep_rew_mean      | 390      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 652      |
# |    fps              | 169      |
# |    time_elapsed     | 579      |
# |    total_timesteps  | 98067    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.65     |
# |    n_updates        | 97066    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 386      |
# |    ep_rew_mean      | 386      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 656      |
# |    fps              | 170      |
# |    time_elapsed     | 583      |
# |    total_timesteps  | 99617    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.19     |
# |    n_updates        | 98616    |
# ----------------------------------

# %%
model.save("dqn_lunarlander")

# %%
model = DQN.load("dqn_lunarlander")

# %%
# Evaluate the trained agent
env = gym.make("CartPole-v1",render_mode="human")
observation,info = env.reset()

while(True):
    action, _ = model.predict(observation, deterministic=True)
    observation, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
    env.render()
    if done:
        break
# Out:
# /home/chessy/myenv/lib/python3.12/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %%
env = gym.make("CartPole-v1")
for i in range(5):
    obs, info = env.reset()
    done = False
    steps = 0

    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        steps += 1

    print(f"Episode {i+1}: {steps} steps")

env.close()
# Out:
# Episode 1: 500 steps
# Episode 2: 500 steps
# Episode 3: 500 steps
# Episode 4: 500 steps
# Episode 5: 500 steps
